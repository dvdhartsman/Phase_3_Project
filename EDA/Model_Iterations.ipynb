# %%
import numpy as np
import pandas as pd

import statsmodels.api as sm

from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, FunctionTransformer, PolynomialFeatures
from sklearn.impute import SimpleImputer, MissingIndicator
from sklearn.metrics import mean_squared_error, ConfusionMatrixDisplay, confusion_matrix, recall_score, \
    accuracy_score, precision_score, f1_score, plot_confusion_matrix, classification_report, roc_auc_score,\
    plot_roc_curve, plot_precision_recall_curve

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer, make_column_selector as selector
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImPipeline

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../data/logistic_model_features.csv", index_col=0)

# %%
df.head(2)
# Out:
#       id  amount_tsh  gps_height  longitude  latitude  population  \
# 0  69572      6000.0        1390  34.938093 -9.856322       109.0
# 1   8776         NaN        1399  34.698766 -2.147466       280.0
#
#    construction_year funder installer       basin  region  region_code  \
# 0             1999.0  Roman     Roman  Lake Nyasa  Iringa           11
# 1             2010.0  other     other   dif_other    Mara           20
#
#    district_code        lga   ward scheme_management scheme_name permit  \
# 0              5      other  other               VWC       Roman  False
# 1              2  Serengeti  Natta             Other         NaN   True
#
#   extraction_type management       payment water_quality      quantity  \
# 0         gravity        vwc  pay annually          soft        enough
# 1         gravity        wug     never pay          soft  insufficient
#
#                  source source_class     waterpoint_type status_group
# 0                spring  groundwater  communal standpipe   functional
# 1  rainwater harvesting      surface  communal standpipe   functional

# %% [markdown]
# Doing final preparation of data, flattening and converting

# %%
df['permit'] = df['permit'].astype(str)
df['region_code'] = df['region_code'].astype(str)
df['district_code'] = df['district_code'].astype(str)

# %%
# Re-filling zeros in amount_tsh

df['amount_tsh'].fillna(0, inplace=True)

# %%
ohe = OneHotEncoder(sparse=False)
target = pd.DataFrame(ohe.fit_transform(df[['status_group']]), index=df.index, columns=[
    'Functional', "Needs_Repair", "Non-Functional"])

# %%
y_flat = np.argmax(np.array(target), axis=1)

y_flat
dbl_check = pd.Series(y_flat, name='Target')

# %% [markdown]
# ### After several model iterations, I am going to investigate the data a bit further, and perhaps clean some more columns.

# %%
original_features = pd.read_csv('../Data/4910797b-ee55-40a7-8668-10efd5c1b960.csv')

# %%
original_features.shape
# Out:
# (59400, 40)

# %% [markdown]
# Looking into datetime information.

# %% [markdown]
# ### Public Meeting, management_group, subvillage,  addition

# %%
original_features['subvillage'].value_counts()[55:60]
# Out:
# Mpakani     53
# Msufini     52
# Dodoma      52
# Kaloleni    51
# Magomeni    51
# Name: subvillage, dtype: int64

# %%
to_replace = original_features["subvillage"].value_counts()[
    original_features["subvillage"].value_counts() < 51].index.values

# creating a new dataframe for safety with binned 'subvillage' values
villages =  original_features.replace(to_replace, value="other").copy() 
# villages.value_counts()

# %%
original_features.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe

# %%
villages.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin subvillage region  region_code  district_code  \
# 0               Lake Nyasa      other  other           11              5
# 1            Lake Victoria      other  other           20              2
# 2                    other    Majengo  other           21              4
# 3  Ruvuma / Southern Coast      other  other           90             63
# 4            Lake Victoria      other  other           18              1
#
#         lga        ward  population public_meeting              recorded_by  \
# 0     other    Mundindi         109           True  GeoData Consultants Ltd
# 1     other       Natta         280            NaN  GeoData Consultants Ltd
# 2     other       other         250           True  GeoData Consultants Ltd
# 3  Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4     other  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe

# %% [markdown]
# I am selecting additional features to add to my model. I have now found that the subvillages can be added, but i binned all of the subvillages with fewer than 60 occurences.

# %%
add_features = villages[['id', 'public_meeting', 'management_group', 'subvillage']]

# %%
more_features = pd.merge(df, add_features, on='id')

# %%
more_features.head(2)
# Out:
#    Unnamed: 0     id  amount_tsh  gps_height  longitude  latitude  population  \
# 0           0  69572      6000.0        1390  34.938093 -9.856322       109.0
# 1           1   8776         0.0        1399  34.698766 -2.147466       280.0
#
#    construction_year funder installer       basin  region region_code  \
# 0             1999.0  Roman     Roman  Lake Nyasa  Iringa          11
# 1             2010.0  other     other   dif_other    Mara          20
#
#   district_code        lga   ward scheme_management scheme_name permit  \
# 0             5      other  other               VWC       Roman  False
# 1             2  Serengeti  Natta             Other         NaN   True
#
#   extraction_type management       payment water_quality      quantity  \
# 0         gravity        vwc  pay annually          soft        enough
# 1         gravity        wug     never pay          soft  insufficient
#
#                  source source_class     waterpoint_type status_group  \
# 0                spring  groundwater  communal standpipe   functional
# 1  rainwater harvesting      surface  communal standpipe   functional
#
#    days_passed public_meeting management_group subvillage
# 0          995           True       user-group      other
# 1          272            NaN       user-group      other

# %%
more_features['amount_tsh'].value_counts()
# Out:
# 0.0         41639
# 500.0        3102
# 50.0         2472
# 1000.0       1488
# 20.0         1463
#             ...
# 8500.0          1
# 6300.0          1
# 220.0           1
# 138000.0        1
# 12.0            1
# Name: amount_tsh, Length: 98, dtype: int64

# %% [markdown]
# # Datetime conversion

# %%
latest_date = pd.to_datetime(original_features['date_recorded']).max()

# %% [markdown]
# Created a total of days passed between "date_recorded" and maximum "data_recorded"

# %%
df['days_passed'] = abs(pd.to_datetime(original_features['date_recorded']) - latest_date)

# %%
df['days_passed'] = df['days_passed'].dt.days

# %% [markdown]
# Looking at revising the features i have selected.

# %%
original_features['']

# %% [markdown]
# Mine, 'gps_height', 'longitude', 'latitude', ,
#        , , , , ,
#        'region_code', 'district_code', , ,
#        'scheme_name', , , 'management', ,
#        , , ,
#        ],
#
#
# Irwin's       'subvillage', , , , , 'public_meeting',
#        'recorded_by', , ,,
#        , , , , , 'waterpoint_type_group']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         59400 non-null  int64
#  1   id                 59400 non-null  int64
#  2   amount_tsh         59400 non-null  float64
#  3   gps_height         59400 non-null  int64
#  4   longitude          57588 non-null  float64
#  5   latitude           59400 non-null  float64
#  6   population         38019 non-null  float64
#  7   construction_year  38691 non-null  float64
#  8   funder             55765 non-null  object
#  9   installer          55745 non-null  object
#  10  basin              59400 non-null  object
#  11  region             59400 non-null  object
#  12  region_code        59400 non-null  object
#  13  district_code      59400 non-null  object
#  14  lga                59400 non-null  object
#  15  ward               59400 non-null  object
#  16  scheme_management  55523 non-null  object
#  17  scheme_name        31234 non-null  object
#  18  permit             59400 non-null  object
#  19  extraction_type    59400 non-null  object
#  20  management         59400 non-null  object
#  21  payment            59400 non-null  object
#  22  water_quality      59400 non-null  object
#  23  quantity           59400 non-null  object
#  24  source             59400 non-null  object
#  25  source_class       59400 non-null  object
#  26  waterpoint_type    59400 non-null  object
#  27  status_group       59400 non-null  object
#  28  days_passed        59400 non-null  int64
# dtypes: float64(5), int64(4), object(20)
# memory usage: 13.1+ MB

# %% [markdown]
# After adding this new dates-passed information, i will retest some models.

# %%
df['latitude'].describe()
# Out:
# count    5.940000e+04
# mean    -5.706033e+00
# std      2.946019e+00
# min     -1.164944e+01
# 25%     -8.540621e+00
# 50%     -5.021597e+00
# 75%     -3.326156e+00
# max     -2.000000e-08
# Name: latitude, dtype: float64

# %%
dbl_check
# Out:
# 0        0
# 1        0
# 2        0
# 3        2
# 4        0
#         ..
# 59395    0
# 59396    0
# 59397    0
# 59398    0
# 59399    0
# Name: Target, Length: 59400, dtype: int64

# %%
pd.concat([more_features.drop(["Unnamed: 0", 'id'], axis=1), dbl_check], axis=1)
# Out:
#        amount_tsh  gps_height  longitude   latitude  population  \
# 0          6000.0        1390  34.938093  -9.856322       109.0
# 1             0.0        1399  34.698766  -2.147466       280.0
# 2            25.0         686  37.460664  -3.821329       250.0
# 3             0.0         263  38.486161 -11.155298        58.0
# 4             0.0           0  31.130847  -1.825359         NaN
# ...           ...         ...        ...        ...         ...
# 59395        10.0        1210  37.169807  -3.253847       125.0
# 59396      4700.0        1212  35.249991  -9.070629        56.0
# 59397         0.0           0  34.017087  -8.750434         NaN
# 59398         0.0           0  35.861315  -6.378573         NaN
# 59399         0.0         191  38.104048  -6.747464       150.0
#
#        construction_year           funder  installer                    basin  \
# 0                 1999.0            Roman      Roman               Lake Nyasa
# 1                 2010.0            other      other                dif_other
# 2                 2009.0            other  dif_other                  Pangani
# 3                 1986.0            other  dif_other  Ruvuma / Southern Coast
# 4                    NaN            other      other                dif_other
# ...                  ...              ...        ...                      ...
# 59395             1999.0  Germany Republi        CES                  Pangani
# 59396             1996.0            other      other                   Rufiji
# 59397                NaN              NaN        NaN                   Rufiji
# 59398                NaN            other      other                   Rufiji
# 59399             2002.0       World Bank      World              Wami / Ruvu
#
#             region region_code district_code             lga  \
# 0           Iringa          11             5           other
# 1             Mara          20             2       Serengeti
# 2          Manyara          21             4       Simanjiro
# 3           Mtwara          90            63           other
# 4            other          18             1         Karagwe
# ...            ...         ...           ...             ...
# 59395  Kilimanjaro           3             5             Hai
# 59396       Iringa          11             4          Njombe
# 59397        Mbeya          12             7         Mbarali
# 59398       Dodoma           1             4        Chamwino
# 59399     Morogoro           5             2  Morogoro Rural
#
#                    ward scheme_management                  scheme_name permit  \
# 0                 other               VWC                        Roman  False
# 1                 Natta             Other                          NaN   True
# 2                 other               VWC                    dif_other   True
# 3                 other               VWC                          NaN   True
# 4                 other               NaN                          NaN   True
# ...                 ...               ...                          ...    ...
# 59395  Masama Magharibi             other       Losaa Kia water supply   True
# 59396             other               VWC  Ikondo electrical water sch   True
# 59397           Chimala               VWC                          NaN  False
# 59398             other               VWC                          NaN   True
# 59399        Ngerengere               VWC                          NaN   True
#
#       extraction_type management                payment water_quality  \
# 0             gravity        vwc           pay annually          soft
# 1             gravity        wug              never pay          soft
# 2             gravity        vwc         pay per bucket          soft
# 3         submersible        vwc              never pay          soft
# 4             gravity      other              never pay          soft
# ...               ...        ...                    ...           ...
# 59395         gravity      other         pay per bucket          soft
# 59396         gravity        vwc           pay annually          soft
# 59397          swn 80        vwc            pay monthly      fluoride
# 59398     nira/tanira        vwc              never pay          soft
# 59399     nira/tanira        vwc  pay when scheme fails         salty
#
#            quantity                source source_class  \
# 0            enough                spring  groundwater
# 1      insufficient  rainwater harvesting      surface
# 2            enough                   dam      surface
# 3               dry           machine dbh  groundwater
# 4          seasonal  rainwater harvesting      surface
# ...             ...                   ...          ...
# 59395        enough                spring  groundwater
# 59396        enough                 river      surface
# 59397        enough           machine dbh  groundwater
# 59398  insufficient          shallow well  groundwater
# 59399        enough          shallow well  groundwater
#
#                    waterpoint_type    status_group  days_passed  \
# 0               communal standpipe      functional          995
# 1               communal standpipe      functional          272
# 2      communal standpipe multiple      functional          281
# 3      communal standpipe multiple  non functional          309
# 4               communal standpipe      functional          874
# ...                            ...             ...          ...
# 59395           communal standpipe      functional          214
# 59396           communal standpipe      functional          941
# 59397                    hand pump      functional          967
# 59398                    hand pump      functional         1001
# 59399                    hand pump      functional          986
#
#       public_meeting management_group subvillage  Target
# 0               True       user-group      other       0
# 1                NaN       user-group      other       0
# 2               True       user-group    Majengo       0
# 3               True       user-group      other       2
# 4               True            other      other       0
# ...              ...              ...        ...     ...
# 59395           True       user-group      other       0
# 59396           True       user-group      other       0
# 59397           True       user-group      other       0
# 59398           True       user-group      other       0
# 59399           True       user-group      other       0
#
# [59400 rows x 31 columns]

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.heatmap(pd.concat([more_features.drop(["Unnamed: 0", 'id'], axis=1), dbl_check], axis=1).corr(), annot=True, ax=ax);

# %% [markdown]
# # Assigned values to X and y
# ### Had been using 'df' as variable, now using 'more_features'

# %%
X = more_features.drop(['status_group', 'Unnamed: 0', 'id'], axis=1)
y = dbl_check

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.543081
# 2    0.384242
# 1    0.072677
# Name: Target, dtype: float64

# %%
X.shape
# Out:
# (59400, 29)

# %%
X.head(2)
# Out:
#    amount_tsh  gps_height  longitude  latitude  population  construction_year  \
# 0      6000.0        1390  34.938093 -9.856322       109.0             1999.0
# 1         0.0        1399  34.698766 -2.147466       280.0             2010.0
#
#   funder installer       basin  region region_code district_code        lga  \
# 0  Roman     Roman  Lake Nyasa  Iringa          11             5      other
# 1  other     other   dif_other    Mara          20             2  Serengeti
#
#     ward scheme_management scheme_name permit extraction_type management  \
# 0  other               VWC       Roman  False         gravity        vwc
# 1  Natta             Other         NaN   True         gravity        wug
#
#         payment water_quality      quantity                source  \
# 0  pay annually          soft        enough                spring
# 1     never pay          soft  insufficient  rainwater harvesting
#
#   source_class     waterpoint_type  days_passed public_meeting  \
# 0  groundwater  communal standpipe          995           True
# 1      surface  communal standpipe          272            NaN
#
#   management_group subvillage
# 0       user-group      other
# 1       user-group      other

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (44550, 29)

# %% [markdown]
# # Class creation

# %%
models = []

# %%
class Model():
    model_list = []
    model_df = pd.DataFrame([[0, 0, 0]], columns=["Name", "train_score", "test_score"])
    
    def __init__(self, name, model):
        self.name = name
        self.params = model.get_params
        self.train_score = model.score(X_train, y_train)
        self.test_score = model.score(X_test, y_test)
    
        Model.model_list.append(self)
        attributes = np.array([self.name, self.train_score, self.test_score])
        self.attributes = attributes
        
        self.attributes_df = pd.DataFrame([attributes], columns=['Name', 'train_score', 'test_score'])
        Model.model_df = pd.concat([Model.model_df, self.attributes_df], axis=0)

    @classmethod
    def get_model_list(cls):
        return cls.model_list

# %% [markdown]
# # Functions

# %%
def catalogue(model, X_train, X_test, y_train, y_test):
    model = Model(model)
    global models
    return model

# %%
def record(model, X_train, X_test, y_train, y_test):
    stats = np.array(model.get_params, model.score(X_train, y_train), model.score(X_test, y_test))
    df = pd.DataFrame(stats, columns=["parameters", "train_score", 'test_score'])
    return df

# %% [markdown]
# # Pipeline construction

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44550 entries, 35240 to 49783
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   amount_tsh         44550 non-null  float64
#  1   gps_height         44550 non-null  int64
#  2   longitude          43195 non-null  float64
#  3   latitude           44550 non-null  float64
#  4   population         28541 non-null  float64
#  5   construction_year  29050 non-null  float64
#  6   funder             41815 non-null  object
#  7   installer          41804 non-null  object
#  8   basin              44550 non-null  object
#  9   region             44550 non-null  object
#  10  region_code        44550 non-null  object
#  11  district_code      44550 non-null  object
#  12  lga                44550 non-null  object
#  13  ward               44550 non-null  object
#  14  scheme_management  41626 non-null  object
#  15  scheme_name        23413 non-null  object
#  16  permit             44550 non-null  object
#  17  extraction_type    44550 non-null  object
#  18  management         44550 non-null  object
#  19  payment            44550 non-null  object
#  20  water_quality      44550 non-null  object
#  21  quantity           44550 non-null  object
#  22  source             44550 non-null  object
#  23  source_class       44550 non-null  object
#  24  waterpoint_type    44550 non-null  object
#  25  days_passed        44550 non-null  int64
#  26  public_meeting     42082 non-null  object
#  27  management_group   44550 non-null  object
#  28  subvillage         44284 non-null  object
# dtypes: float64(5), int64(2), object(22)
# memory usage: 10.2+ MB

# %%
subpipe_numerics = Pipeline(steps=[
    ('mean_impute', SimpleImputer(add_indicator=True, strategy='mean')),
    ('ss', StandardScaler())
])

sub_pipe_cat = Pipeline(steps=[
    
    ('cat_impute', SimpleImputer(strategy='most_frequent', add_indicator=True)),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse=True))  # sparse=False in failed version
], verbose=True)  # verbose = False on failed version

# %%
CT = ColumnTransformer(transformers=[
    ('subpipe_numerics', subpipe_numerics, selector(dtype_include=np.number)),
    ('subpipe_cat', sub_pipe_cat, selector(dtype_include=object))
], remainder='passthrough', n_jobs= -1)

# %%
add_features1 = Pipeline(steps=[
    ('CT', CT),
    ('add_features1', LogisticRegression(max_iter=1000, n_jobs= -1, multi_class="multinomial", 
    solver='newton-cg', tol=.0001, C=0.1))
], verbose=True)

# %% [markdown]
# ### Reference for hyperparameters

# %%
('poly2',
                 LogisticRegression(C=0.1, fit_intercept=False, max_iter=200,
                                    multi_class='multinomial', n_jobs=-1,
                                    solver='newton-cg', tol=0.01))],
         verbose=True)
# Out:
#   File "<ipython-input-569-2b8685ac1879>", line 4
#     solver='newton-cg', tol=0.01))],
#                                   ^
# SyntaxError: unmatched ']'

# %% [markdown]
# ### Optional Smoting

# %%
poly_smote = ImPipeline(steps=[
    ('ct', CT),
    ('sm', SMOTE(random_state=42, sampling_strategy='auto')),
    ('poly_smote', LogisticRegression(n_jobs= -1, C=0.1, max_iter=200, tol=.01, 
        multi_class="multinomial", solver='newton-cg', fit_intercept=False))
])

# %% [markdown]
# # ACTUAL PIPELINE FITTING!

# %%
add_features1.fit(X_train, y_train)
# Out:
# [Pipeline] ................ (step 1 of 2) Processing CT, total=  10.9s
# [Pipeline] ..... (step 2 of 2) Processing add_features1, total=  13.9s
# Pipeline(steps=[('CT',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('subpipe_numerics',
#                                                   Pipeline(steps=[('mean_impute',
#                                                                    SimpleImputer(add_indicator=True)),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51ba590a0>),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('cat_impute',
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))],
#                                                            verbose=True),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51ba59940>)])),
#                 ('add_features1',
#                  LogisticRegression(C=0.1, max_iter=1000,
#                                     multi_class='multinomial', n_jobs=-1,
#                                     solver='newton-cg'))],
#          verbose=True)

# %% [markdown]
# # Instantiation of models

# %%
add_features1.score(X_train, y_train), add_features1.score(X_test, y_test)
# Out:
# (0.7686644219977553, 0.7655218855218855)

# %%
log_loss = cross_val_score(add_features1, X_train, y_train, scoring='neg_log_loss', n_jobs=-1)

# %%
-np.mean(log_loss)
# Out:
# 0.5817625801307812

# %%
log_model1.train_score, log_model1.train_score
# no real difference, so i will try some other shit
# Out:
# (0.7699214365881033, 0.7699214365881033)

# %%
dates = Model("dates1", dates_passed)

# %%
model_1.train_score, model_1.test_score
# Out:
# (0.6697418630751965, 0.665050505050505)

# %%
log_model1 = Model("Baseline_log", log_model)

# %%
Model.model_df
# Out:
#                 Name         train_score          test_score
# 0                  0                   0                   0
# 0           baseline  0.6697418630751965   0.665050505050505
# 0        Smote_grid1  0.6697418630751965   0.665050505050505
# 0       Baseline_log  0.7699214365881033  0.7650505050505051
# 0       Baseline_log  0.7699214365881033  0.7650505050505051
# 0  Baseline_log_grid  0.7668462401795735  0.7647811447811448
# 0              poly1  0.7724354657687991  0.7688215488215489
# 0        Poly_grid_1  0.7724354657687991  0.7688215488215489
# 0              poly2  0.7701683501683502  0.7661279461279461
# 0        Poly_grid_3  0.7724354657687991  0.7688215488215489
# 0         poly_smote   0.684040404040404   0.677979797979798
# 0             dates1  0.7688215488215489  0.7637710437710438

# %%
for i in add_features1.get_params().keys():
    print(i)
# Out:
# memory
# steps
# verbose
# CT
# add_features1
# CT__n_jobs
# CT__remainder
# CT__sparse_threshold
# CT__transformer_weights
# CT__transformers
# CT__verbose
# CT__subpipe_numerics
# CT__subpipe_cat
# CT__subpipe_numerics__memory
# CT__subpipe_numerics__steps
# CT__subpipe_numerics__verbose
# CT__subpipe_numerics__mean_impute
# CT__subpipe_numerics__ss
# CT__subpipe_numerics__mean_impute__add_indicator
# CT__subpipe_numerics__mean_impute__copy
# CT__subpipe_numerics__mean_impute__fill_value
# CT__subpipe_numerics__mean_impute__missing_values
# CT__subpipe_numerics__mean_impute__strategy
# CT__subpipe_numerics__mean_impute__verbose
# CT__subpipe_numerics__ss__copy
# CT__subpipe_numerics__ss__with_mean
# CT__subpipe_numerics__ss__with_std
# CT__subpipe_cat__memory
# CT__subpipe_cat__steps
# CT__subpipe_cat__verbose
# CT__subpipe_cat__cat_impute
# CT__subpipe_cat__ohe
# CT__subpipe_cat__cat_impute__add_indicator
# CT__subpipe_cat__cat_impute__copy
# CT__subpipe_cat__cat_impute__fill_value
# CT__subpipe_cat__cat_impute__missing_values
# CT__subpipe_cat__cat_impute__strategy
# CT__subpipe_cat__cat_impute__verbose
# CT__subpipe_cat__ohe__categories
# CT__subpipe_cat__ohe__drop
# CT__subpipe_cat__ohe__dtype
# CT__subpipe_cat__ohe__handle_unknown
# CT__subpipe_cat__ohe__sparse
# add_features1__C
# add_features1__class_weight
# add_features1__dual
# add_features1__fit_intercept
# add_features1__intercept_scaling
# add_features1__l1_ratio
# add_features1__max_iter
# add_features1__multi_class
# add_features1__n_jobs
# add_features1__penalty
# add_features1__random_state
# add_features1__solver
# add_features1__tol
# add_features1__verbose
# add_features1__warm_start

# %%
# poly_model2.get_params

# %%
params = {
    'add_features1__solver' : ['newton-cg'],  # 'newton-cholesky' not supported in logistic regression
    'add_features1__max_iter': [800, 700, 600, 500],
    'add_features1__C' : [0.01, .1, .001, 1],
    'add_features1__tol' : [.01, .1, .001],
    "add_features1__penalty" : ['l1', 'l2', 'elasticnet', 'none']
}

# %%
gs = GridSearchCV(
    estimator= add_features1,     # Subset pipeline
    param_grid=params,
    cv=5,
    verbose=2,
    n_jobs=-1)

# %%
# %%time
gs.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 77.4min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed eval> in <module>
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/anaconda3/envs/learn-env/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/envs/learn-env/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/envs/learn-env/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
gs.best_estimator_
# Out:
# Pipeline(steps=[('CT',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('subpipe_numerics',
#                                                   Pipeline(steps=[('mean_impute',
#                                                                    SimpleImputer(add_indicator=True)),
#                                                                   ('ss',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51d0332b0>),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('cat_i...
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  fill_value='Missing',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))],
#                                                            verbose=True),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff6a6b6fc10>)])),
#                 ('dates',
#                  LogisticRegression(C=1, fit_intercept=False, max_iter=200,
#                                     multi_class='multinomial', n_jobs=-1,
#                                     solver='newton-cg', tol=0.01))],
#          verbose=True)

# %%
gs.best_params_
# Out:
# {'dates__C': 1,
#  'dates__max_iter': 200,
#  'dates__solver': 'newton-cg',
#  'dates__tol': 0.01}

# %%
dates = gs.best_estimator_
dates.fit(X_train, y_train)
# Out:
# [Pipeline] ................ (step 1 of 2) Processing CT, total=   0.8s
# [Pipeline] ............. (step 2 of 2) Processing dates, total= 1.1min
# Pipeline(steps=[('CT',
#                  ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                                    transformers=[('subpipe_numerics',
#                                                   Pipeline(steps=[('mean_impute',
#                                                                    SimpleImputer(add_indicator=True)),
#                                                                   ('ss',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51d0332b0>),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('cat_i...
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  fill_value='Missing',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))],
#                                                            verbose=True),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff6a6b6fc10>)])),
#                 ('dates',
#                  LogisticRegression(C=1, fit_intercept=False, max_iter=200,
#                                     multi_class='multinomial', n_jobs=-1,
#                                     solver='newton-cg', tol=0.01))],
#          verbose=True)

# %%
# poly_3_grid

# %%
dates.score(X_train, y_train), dates.score(X_test, y_test)
# Out:
# (0.7722558922558923, 0.7679461279461279)

# %%
dates_grid = Model("Dates_grid", dates)

# %%
print(classification_report(y_test, dates.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82      8065
#            1       0.53      0.18      0.27      1079
#            2       0.80      0.71      0.75      5706
#
#     accuracy                           0.77     14850
#    macro avg       0.70      0.59      0.61     14850
# weighted avg       0.76      0.77      0.75     14850

# %%
Model.model_df
# Out:
#                 Name         train_score          test_score
# 0                  0                   0                   0
# 0           baseline  0.6697418630751965   0.665050505050505
# 0        Smote_grid1  0.6697418630751965   0.665050505050505
# 0       Baseline_log  0.7699214365881033  0.7650505050505051
# 0       Baseline_log  0.7699214365881033  0.7650505050505051
# 0  Baseline_log_grid  0.7668462401795735  0.7647811447811448
# 0              poly1  0.7724354657687991  0.7688215488215489
# 0        Poly_grid_1  0.7724354657687991  0.7688215488215489
# 0              poly2  0.7701683501683502  0.7661279461279461
# 0        Poly_grid_3  0.7724354657687991  0.7688215488215489
# 0         poly_smote   0.684040404040404   0.677979797979798
# 0             dates1  0.7688215488215489  0.7637710437710438
# 0         Dates_grid  0.7722558922558923  0.7679461279461279

# %%
for i in Model.model_list:
    print(i.name)
# Out:
# baseline
# Smote_grid1
# Baseline_log
# Baseline_log
# Baseline_log_grid
# poly1
# Poly_grid_1
# poly2
# Poly_grid_3
# poly_smote
# dates1
# Dates_grid

# %%
Model.model_list[5].train_score
# Out:
# 0.7724354657687991

# %%
Model.model_list[5].params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('CT',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_numerics',
#                                                   Pipeline(steps=[('mean_impute',
#                                                                    SimpleImputer(add_indicator=True)),
#                                                                   ('ss',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51d5101f0>),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('cat_impute',
#                                                                    SimpleImputer(add_indicator=True,
#                                                                                  fill_value='Missing',
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))],
#                                                            verbose=True),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff51d5105e0>)])),
#                 ('log',
#                  LogisticRegression(fit_intercept=False, max_iter=200,
#                                     multi_class='multinomial', n_jobs=-1,
#                                     solver='newton-cg', tol=1))])>

# %%
Model.model_df.to_csv('/Users/samalainabayeva/Desktop/Water Project CSVs/abridged_table.csv')

# %%
baseline = Model.model_list[0]
baseline.params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('subpipe_numerics',
#                                                   Pipeline(steps=[('mean_impute',
#                                                                    SimpleImputer(add_indicator=True)),
#                                                                   ('ss',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff59f4e14f0>),
#                                                  ('subpipe_cat',
#                                                   Pipeline(steps=[('cat_impute',
#                                                                    SimpleImputer(add_indicator=True,...
#                                                                                  strategy='constant')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))],
#                                                            verbose=True),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7ff59f4e1760>)])),
#                 ('sm',
#                  SMOTE(random_state=42, sampling_strategy='not majority')),
#                 ('smote_trial',
#                  LogisticRegression(C=0.01, fit_intercept=False, max_iter=200,
#                                     multi_class='multinomial', n_jobs=-1,
#                                     solver='newton-cg'))])>

# %% [markdown]
# # Observations:
# - Changing sampling strategy to "auto" made no difference in SMOTE hyperparameters.
# - Baseline log grid slightly worse than the uncalibrated logistic regression
# - For polynomial features, the grid search did not improve the default settings at all, still not overfit
# - After a 2 hour grid search, the best model only equals the best score thus far, still without overfitting, but without any improvement either.
# - Polynomial degree 2 + smote improved upon the baseline smote, but still performed worse than other models
# # I will revisit the model features in the morning
# - Adding the dates_passed column improved the model very slightly. I will now re-check cleaning/feature selection.

# %%
class ModelsList():
    def init(self, x,y):
        xtrain, xtest, ytrain, ytest = train_test_split(x,y)
        self.xtrain = xtrain
        self.xtest = xtest
        self.ytrain = ytrain
        self.ytest = ytest
        self.df = pd.DataFrame({'Model' : pd.Series(dtype='str'), 
                    'train_score' : pd.Series(dtype='float64'), 
                    'test_score': pd.Series(dtype='float64'),
                    'params': pd.Series(dtype='O')})

    def update(self, estimator, name, fit = True, params = None):
        if fit:
            estimator.fit(self.xtrain, self.ytrain)

        trainscore = estimator.score(self.xtrain, self.ytrain)
        testscore = estimator.score(self.xtest, self.ytest)
        model_to_add = [name, trainscore, testscore, params]
        self.df.loc[len(self.df.index)] = model_to_add
